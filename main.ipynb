# %%
import os
import pandas as pd
import valentine
from valentine import valentine_match, valentine_metrics
from valentine.algorithms import Coma, Cupid
import pprint
import json

# %%
# load data from dataset/monitor_specs folder, there's a folder for each source and each file json file contains the specs for a monitor
sources2monitors = {}

for folder in os.listdir('dataset/monitor_specs'):
    monitors = []
    for file in os.listdir('dataset/monitor_specs/' + folder):
        with open('dataset/monitor_specs/' + folder + '/' + file) as f:
            monitor = json.load(f)
            monitors.append(monitor)
            if folder in sources2monitors:
                sources2monitors[folder].append(monitor)
            else:
                sources2monitors[folder] = [monitor]

# %%
sources2monitors.get('www.ebay.com').__len__()
# Out:
# 4281

# %%
# from the dict source2monitors, we get all the unique attributes for each source and count how many times they appear
sources2attributes = {}

for source in sources2monitors:
    attributes = {}
    for monitor in sources2monitors.get(source):
        for attribute in monitor.keys():
            if attribute in attributes:
                attributes[attribute] += 1
            else:
                attributes[attribute] = 1
    sources2attributes[source] = attributes

# %%
sources2attributes.get('www.ebay.com')
# Out:
# {'<page title>': 4281,
#  'brand': 2148,
#  'condition': 2405,
#  'display technology': 3247,
#  'screen size': 3495,
#  'aspect ratio': 2806,
#  'brightness': 2173,
#  'contrast ratio': 2733,
#  'max resolution': 1205,
#  'model': 3055,
#  'mpn': 2400,
#  'response time': 2715,
#  'video inputs': 1654,
#  'countryregion of manufacture': 125,
#  'max. resolution': 1206,
#  'system': 1442,
#  'upc': 1762,
#  'country/region of manufacture': 90,
#  'features': 909,
#  'adjustable display angle': 269,
#  'adjustable display height': 101,
#  'audio': 97,
#  'backlight technology': 390,
#  'brand name': 381,
#  'builtin devices': 121,
#  'color': 227,
#  'color supported': 289,
#  'depth': 310,
#  'dvi': 149,
#  'general information': 159,
#  'green compliance certificateauthority': 278,
#  'hdcp supported': 220,
#  'hdmi': 117,
#  'headphone': 40,
#  'horizontal viewing angle': 312,
#  'input voltage': 148,
#  'interfacesports': 171,
#  'manufacturer': 580,
#  'manufacturer part number': 292,
#  'maximum resolution': 508,
#  'miscellaneous': 403,
#  'number of screens': 329,
#  'physical characteristics': 171,
#  'platform supported': 110,
#  'power description': 153,
#  'product model': 299,
#  'product name': 289,
#  'product series': 131,
#  'product type': 397,
#  'screen mode': 378,
#  'speakers': 198,
#  'standard refresh rate': 189,
#  'standby power consumption': 185,
#  'technical information': 170,
#  'vertical viewing angle': 354,
#  'vesa mount compatible': 161,
#  'vesa mount standard': 116,
#  'video': 174,
#  'weight approximate': 159,
#  'width': 296,
#  'manufacturer website address': 114,
#  'manufacturersupplier': 52,
#  'panel technology': 139,
#  'product line': 337,
#  'audio output': 56,
#  'cable': 42,
#  'cable details': 31,
#  'color support': 214,
#  'comments': 25,
#  'compatibility': 74,
#  'details': 25,
#  'diagonal size': 42,
#  'diagonal size metric': 43,
#  'dimensions  weight': 55,
#  'dimensions  weight details': 35,
#  'display': 52,
#  'display projector': 48,
#  'environmental standards': 51,
#  'form factor': 240,
#  'header': 58,
#  'height': 222,
#  'image aspect ratio': 46,
#  'image contrast ratio': 75,
#  'input device': 54,
#  'input signal': 48,
#  'interface': 48,
#  'interfaces': 58,
#  'lcd backlight technology': 45,
#  'nominal voltage': 39,
#  'packaged quantity': 54,
#  'power consumption operational': 57,
#  'power consumption stand by': 30,
#  'power device': 55,
#  'projector image brightness': 41,
#  'projector monitor features': 33,
#  'technology': 49,
#  'type': 173,
#  'typical response time': 38,
#  'video input': 50,
#  'weight': 164,
#  'additional mpn': 179,
#  'analog video input connector': 168,
#  'max viewing angle horizontal': 182,
#  'max viewing angle vertical': 182,
#  'monitor color': 188,
#  'monitor platform source': 113,
#  'refresh rate': 149,
#  'regulatory approval': 160,
#  'synchronization range  horizontal': 156,
#  'synchronization range  vertical': 159,
#  'backlight type': 18,
#  'brightness typical': 42,
#  'color gamut': 15,
#  'contrast ratio typical': 37,
#  'dimensions w x h x d': 16,
#  'displayable colors': 17,
#  'horizontal analogdigital': 6,
#  'input connectors': 21,
#  'lookup table': 9,
#  'native resolution': 79,
#  'operating altitude': 15,
#  'operating humidity': 19,
#  'operating temperature': 38,
#  'pixel pitch': 141,
#  'pixels per inch': 17,
#  'power consumption': 63,
#  'pwm frequency': 3,
#  'response time typical': 37,
#  'rohs': 9,
#  'storage altitude': 15,
#  'storage humidity': 16,
#  'storage temperature': 17,
#  'tco': 6,
#  'vertical': 10,
#  'vesa hole configuration': 13,
#  'viewable image size': 28,
#  'viewing angle typical': 20,
#  'green compliant': 166,
#  'mfg model': 77,
#  'product family': 59,
#  'unit of measure': 77,
#  '100000001 asus smart contrast ratio': 21,
#  'advanced video technologies for exceptional visuals': 8,
#  'full hd with hdmi': 17,
#  'mount type': 175,
#  'splendid video intelligence technology': 24,
#  'color reproduction range': 13,
#  'dynamic contrast ratio': 61,
#  'virtual 4k 30hz': 4,
#  'power consumption typical': 7,
#  'antiglare coating': 17,
#  'dvid input': 17,
#  'dvid with hdcp input': 16,
#  'energy star certified': 19,
#  'hdmi input': 18,
#  'onscreen image controls': 13,
#  'screen refresh rate': 20,
#  'screen size measured diagonally': 17,
#  'speakers included': 17,
#  'specs': 20,
#  'tilt': 50,
#  'touchscreen': 63,
#  'vga input': 17,
#  'displayport': 88,
#  'adjustable display pivot': 100,
#  'offmode power consumption': 88,
#  'package contents': 182,
#  'screen surface': 111,
#  'connections': 22,
#  'dimensions': 39,
#  'input video signal': 12,
#  'maximum colors': 13,
#  'multimedia speakers': 13,
#  'on mode': 12,
#  'other features': 13,
#  'plug  play': 18,
#  'stand': 32,
#  'sync type': 12,
#  'viewing angle horizontalvertical': 15,
#  'wall mountable': 13,
#  'whats in the box': 13,
#  'additional notes': 6,
#  'category': 6,
#  'shipping dimensions': 8,
#  'shipping weight': 13,
#  'sku': 12,
#  '3d technology': 5,
#  'about the brand': 5,
#  'additional features': 9,
#  'audio type': 3,
#  'audiovideo inputs': 8,
#  'builtin tuner': 4,
#  'definition': 4,
#  'description': 229,
#  'display resolution': 17,
#  'energy star': 8,
#  'family line': 3,
#  'number of speakers': 22,
#  'on mode power': 4,
#  'parental control': 7,
#  'rear input connectors': 3,
#  'remote control type originally supplied by manufacturer': 4,
#  'resolution': 49,
#  'room type': 3,
#  'sleep mode power': 4,
#  'smart tv features': 7,
#  'speaker power': 4,
#  'supported resolutions': 4,
#  'viewing angle': 64,
#  'builtin speakers': 11,
#  'builtin tv tuner': 3,
#  'cabinet color': 25,
#  'complies with': 8,
#  'connectors': 15,
#  'display colors': 41,
#  'dsub': 13,
#  'hdcp support': 5,
#  'horizontal refresh rate': 45,
#  'input video compatibility': 9,
#  'led backlight': 12,
#  'panel': 8,
#  'recommended resolution': 11,
#  'regulatory approvals': 6,
#  'stand adjustments': 22,
#  'usb 20': 4,
#  'vertical refresh rate': 50,
#  'vesa compatible': 5,
#  'widescreen': 69,
#  'normal signs of use are present on this unit': 17,
#  'height with stand': 54,
#  'marketing information': 102,
#  'screensize': 69,
#  'â': 44,
#  'digital video input standard': 111,
#  'release date': 36,
#  'vga': 110,
#  'certifications  standards': 124,
#  'depth with stand': 115,
#  'display orientation': 16,
#  'environmentconscious and reliable': 6,
#  'flexible viewing and connectivity options': 6,
#  'impressive screen clarity': 5,
#  'postconsumerwaste': 10,
#  'recycled content': 12,
#  'usb': 89,
#  'usb standard': 43,
#  'width with stand': 113,
#  'coo': 3,
#  'display diagonal size': 9,
#  'display response time': 9,
#  'display type': 60,
#  'unspsc code': 10,
#  'main features': 35,
#  'mfr part number': 223,
#  'specifications': 193,
#  'weight with stand approximate': 50,
#  'audio line out': 4,
#  'bluetooth': 4,
#  'cache': 7,
#  'display  graphics': 13,
#  'display screen type': 25,
#  'ethernet technology': 14,
#  'graphics controller manufacturer': 4,
#  'graphics controller model': 4,
#  'graphics memory accessibility': 3,
#  'graphics memory technology': 4,
#  'input devices': 12,
#  'keyboard': 7,
#  'memory': 57,
#  'memory card supported': 3,
#  'memory technology': 5,
#  'microphone': 5,
#  'multitouch screen': 9,
#  'network  communication': 4,
#  'network rj45': 7,
#  'operating system': 67,
#  'optical drive type': 5,
#  'processor  chipset': 4,
#  'processor core': 5,
#  'processor model': 5,
#  'processor speed': 61,
#  'processor type': 64,
#  'screen resolution': 18,
#  'software': 18,
#  'standard memory': 14,
#  'storage': 8,
#  'total number of usb ports': 5,
#  'wireless lan': 3,
#  'ean': 34,
#  'power supply': 38,
#  'cables included': 10,
#  'compliant standards': 60,
#  'device type': 8,
#  'dimensions wxdxh': 35,
#  'display position adjustments': 46,
#  'display type ledbacklit lcd monitor  tft active matrix': 5,
#  'energy star qualified': 25,
#  'epeat compliant': 23,
#  'flat panel mount interface': 46,
#  'humidity range operating': 19,
#  'included accessories': 10,
#  'included software': 3,
#  'manufacturer warranty': 27,
#  'max operating temperature': 41,
#  'microsoft certification': 11,
#  'min operating temperature': 40,
#  'panel type': 54,
#  'power consumption stand by  sleep': 10,
#  'product description': 7,
#  'screen coating': 8,
#  'service  support': 53,
#  'service  support 3 years warranty': 4,
#  'service  support details': 24,
#  'viewable size': 53,
#  'voltage required': 10,
#  'contemporary styling': 7,
#  'customizable color': 5,
#  'full hd resolution': 7,
#  'stunning clarity': 6,
#  'superb performance': 9,
#  'versatile connections': 9,
#  'dot acceptable': 4,
#  'plug and play capability': 4,
#  'powersaver': 4,
#  'not included': 6,
#  'ra return authroization': 5,
#  'your paypal payment email address if you pay with paypal': 5,
#  'immediate payment': 19,
#  'nonpaying bidder': 19,
#  'restocking fees': 19,
#  'tax': 19,
#  'we guarantee against doa': 19,
#  'we prefer paypal': 19,
#  'whats not included': 19,
#  'sdcstringscreen size mined': 7,
#  'bundled items': 24,
#  'warranty  labor': 8,
#  'warranty  parts': 8,
#  'country of manufacture': 78,
#  'interface  connectivity': 4,
#  '3d type': 7,
#  'maximum adjustable height': 10,
#  '14day moneyback guarantee': 6,
#  '1501 n michael drive wood dale illinois 60191': 3,
#  '57 business days': 6,
#  'monfri between 1000am and 400pm': 6,
#  'must': 6,
#  'not': 7,
#  'paypal': 6,
#  'please include your phone number': 6,
#  'limited warranty': 32,
#  'green compliance certificate/authority': 15,
#  'standby': 8,
#  'cabinet': 18,
#  'chassis': 18,
#  'country kits': 20,
#  'environmental parameters': 40,
#  'height adjustment': 23,
#  'localization': 25,
#  'power consumption sleep': 7,
#  'product color': 38,
#  'qty': 31,
#  'rotation angle': 14,
#  'service': 47,
#  'support details type': 36,
#  'tilt angle': 73,
#  'video format': 6,
#  'viewable size metric': 28,
#  'vsync rate at max res': 30,
#  'built-in devices': 69,
#  'game mode': 5,
#  'osd languages': 43,
#  'battery': 3,
#  'installed qty': 4,
#  'exterior color': 3,
#  'tv type': 4,
#  'security': 11,
#  'item condition': 7,
#  'ports': 19,
#  'size': 23,
#  'display  color support': 4,
#  'dot pitch  pixel pitch': 3,
#  'header  model': 3,
#  'service  support type': 6,
#  'product information': 71,
#  'weight (approximate)': 44,
#  '162 million colors': 3,
#  '19inch screen': 3,
#  'magicbright2': 3,
#  'magiccolor': 5,
#  '2ms response time': 9,
#  'aspect control function': 11,
#  'assembly required': 5,
#  'country of origin': 19,
#  'digital input': 10,
#  'recycled': 16,
#  'humidity': 6,
#  'os compatibility': 7,
#  'temperature': 10,
#  'usb hub': 5,
#  'wall mount': 3,
#  'contents': 3,
#  'model number': 9,
#  'series': 12,
#  'warranty': 70,
#  'enhanced screen performance': 6,
#  'its easy to be green': 5,
#  'taking care of business never looked so stylish': 3,
#  'wide compatibility for today and tomorrow': 4,
#  'input power': 3,
#  'pc': 8,
#  'screen brightness': 12,
#  'sdc.string.response time (num)': 8,
#  'vesa mount': 11,
#  'color effect': 3,
#  'magicbrightâ³': 3,
#  'magicspeed 5ms': 3,
#  'energy star compliant': 14,
#  'maximum power consumption': 17,
#  'osd language': 3,
#  'power cable': 4,
#  'processor': 6,
#  'speaker type': 10,
#  'typical power consumption': 17,
#  'includes': 3,
#  'dimensions wxhxd': 16,
#  'international buyers': 10,
#  'resolution description': 11,
#  'room': 1,
#  'material': 4,
#  'operating power consumption': 55,
#  'touchscreen type': 43,
#  'ecomode': 8,
#  'multifunctional base design': 8,
#  'multimedia enhanced': 9,
#  'optisync digitalanalog inputs expand your connectivity': 9,
#  'stylish slimbezel design': 8,
#  'widescreen aspect ratio with 1920 x 1080 resolution': 7,
#  'conserve energy': 3,
#  'enjoy the view': 3,
#  'give your productivity a boost with the comfortable design and': 1,
#  'work comfortably': 3,
#  'swivel angle': 30,
#  'a full 14day warranty from the time the item is received': 5,
#  'ebay': 6,
#  'for more information on global shipping click': 5,
#  'auto switch to rear view': 7,
#  'brightness and contrast': 8,
#  'camera tripod screw hole': 11,
#  'image flip l  r and u  d': 10,
#  'connectivity': 6,
#  'dimensions hxwxd': 3,
#  'damaged items': 8,
#  'defective item': 8,
#  'exchanges': 8,
#  'international customers': 8,
#  'international returns': 8,
#  'refunds': 8,
#  'replacement': 8,
#  'resellers  bulk orders policy': 8,
#  'return policy': 22,
#  'return shipping': 8,
#  'returning items': 8,
#  'television returns': 8,
#  'analog tuner': 3,
#  'battery included': 5,
#  'component video': 7,
#  'digital audio output': 5,
#  'digital tuner': 3,
#  'native contrast ratio': 7,
#  'number of hdmi ports': 5,
#  'remote control': 11,
#  'scan format': 4,
#  'video signal standard': 5,
#  'created by': 8,
#  'economy': 20,
#  'expedited': 20,
#  'oneday': 20,
#  'standard': 33,
#  'magic picture controls': 3,
#  'environmental compliance': 5,
#  'input signal sync': 6,
#  'input signal video': 6,
#  'synchronization range horizontal': 6,
#  'synchronization range vertical': 6,
#  'assured compatibility': 9,
#  'designed with the environment in mind': 9,
#  'easy to set up and use': 9,
#  'improve how you view your work': 4,
#  'position the monitor for the way you work best': 9,
#  'display size': 7,
#  'graphics processing type': 39,
#  'condition details': 11,
#  'item description': 11,
#  'item id': 11,
#  'our testing': 11,
#  'sale includes': 11,
#  'video inputs1': 15,
#  'video inputs2': 15,
#  'input video': 5,
#  'assembled depth in': 4,
#  'assembled width in': 5,
#  'certifications and listings': 4,
#  'product height in': 4,
#  'product weight lb': 3,
#  'product width in': 4,
#  'connectivity details type': 28,
#  'frequency required': 28,
#  'multitouch display': 4,
#  'output power channel': 7,
#  'speakers configuration': 8,
#  'support details service included': 25,
#  'system requirements': 11,
#  'audio input': 13,
#  'chipset manufacturer': 3,
#  'chipset model': 3,
#  'hyperthreading': 3,
#  'maximum memory': 3,
#  'memory standard': 3,
#  'number of usb 30 ports': 4,
#  'operating system architecture': 3,
#  'pointing device type': 4,
#  'processor manufacturer': 4,
#  'contrast ratio to 1': 8,
#  'number of dvi': 7,
#  'screen aspect ratio': 7,
#  'viewing angle horizontal': 5,
#  'viewing angle vertical': 12,
#  'display screen coating': 23,
#  'image color temperature': 14,
#  'manufacturer selling program': 8,
#  'tft technology': 22,
#  'video bandwidth': 16,
#  'additional video inputs': 1,
#  'epeat level': 18,
#  'microsoft certifications': 8,
#  'interface type': 5,
#  'vertical frequency': 3,
#  'overall value delivered': 9,
#  'hard drive capacity': 50,
#  'operating system edition': 51,
#  'release year': 10,
#  'support details location': 9,
#  'controls  adjustments': 22,
#  'power consumption stand by sleep': 9,
#  'contact us': 6,
#  'cpu': 4,
#  'hard drive': 9,
#  'optical drive': 6,
#  'sales tax': 3,
#  'screen': 3,
#  'shipping': 4,
#  'sound': 5,
#  'enhanced compatibility': 5,
#  'see more do more': 12,
#  'smart design': 6,
#  'technology with the environment in mind': 5,
#  'total hp computing experience': 7,
#  'responsible': 3,
#  'eizo lcd utility disk': 5,
#  'signal cables': 5,
#  'chipset': 4,
#  'ram': 6,
#  'speed': 3,
#  'wireless': 3,
#  'touchscreen information': 15,
#  'ease of ownership': 4,
#  'precise vivid industrystandard color': 4,
#  'superb user experience': 5,
#  'uncompromising screen performance': 4,
#  'a/c adapter': 14,
#  'included cables': 14,
#  'webcam': 6,
#  'kvm switch': 10,
#  'kvm technology': 1,
#  'interface provided': 10,
#  'networking': 9,
#  'video output': 7,
#  'media drive': 5,
#  'included monitor accessories': 5,
#  'product brand': 2,
#  'product condition': 3,
#  'voltage': 10,
#  'media': 7,
#  'combined shipping take 3 off shipping': 9,
#  'fast response time 5ms': 3,
#  'slim and emotional design': 3,
#  'supports fullhd and movie wide': 3,
#  'vivid and clear image for multimedia contents': 3,
#  'engaging touch experience': 3,
#  'outstanding connectivity': 3,
#  'peace of mind': 4,
#  'sdc.string.screen size (mined)': 5,
#  'sdcstringresponse time num': 3,
#  'wireless technology': 1,
#  'colors': 5,
#  'power': 14,
#  'viewing angles': 13,
#  'ascr asus smart contrast ratio technology': 3,
#  'care for the earth': 5,
#  'audio system': 8,
#  'color depth ja': 5,
#  'comments ja': 4,
#  'connectivity details length': 8,
#  'connector type': 12,
#  'details ja': 4,
#  'diagonal size cm': 8,
#  'dimensions  weight shipping': 8,
#  'display format': 8,
#  'hdcp compatible': 6,
#  'hdmi ports qty': 8,
#  'lcd display technology': 3,
#  'led backlight type': 7,
#  'output power total': 4,
#  'pc interface': 9,
#  'shipping depth': 5,
#  'shipping height': 7,
#  'speaker form factor': 8,
#  'speaker qty': 7,
#  'speaker system details': 8,
#  'stands  mounts': 6,
#  'support details full contract period': 13,
#  'targeting': 8,
#  'television': 8,
#  'tv tuner': 8,
#  'tv tuner presence': 9,
#  'video interface': 9,
#  'video wall components qty': 3,
#  'audio outputs': 12,
#  'brightness cdmâ²': 12,
#  'input power source': 12,
#  'pixel pitch mm': 6,
#  'resolution pixels': 12,
#  'screen size diagonal': 12,
#  'viewing angle degrees': 12,
#  'panel backlight': 3,
#  'number of computers supported': 9,
#  'dvd media': 1,
#  'operating system ****': 2,
#  'stand included:': 1,
#  'color depth': 3,
#  'user controls': 4,
#  'sync': 10,
#  'rms output power': 4,
#  'assembled height in': 4,
#  'display area': 9,
#  'vesa wall mounting': 3,
#  'viewing angle hv': 4,
#  'frequency': 9,
#  'power management': 23,
#  'sale does not include': 7,
#  'daisy chain': 5,
#  'ps2 port': 4,
#  'backlight': 23,
#  'backlight life': 6,
#  'consumption': 8,
#  'digital': 5,
#  'mac': 5,
#  'optimum resolution': 12,
#  'panel surface': 8,
#  'physical with stand': 7,
#  'physical without stand': 7,
#  'regulations': 9,
#  'doa dead on arrival': 4,
#  'â condition': 4,
#  'â manufacturer': 4,
#  'â model number': 4,
#  'â quantity included': 4,
#  'â sales includes': 4,
#  'â warranty': 4,
#  'brightness stabilization': 8,
#  'digital uniformity equalizer': 8,
#  'grayscale tones': 10,
#  'height adjustment range': 22,
#  'hole spacing vesa standard': 15,
#  'humidity rh non condensing': 4,
#  'input terminals': 21,
#  'monitor type': 8,
#  'pivot': 21,
#  'power requirements': 26,
#  'power save mode': 26,
#  'preset modes': 18,
#  'recommended brightness for calibration': 6,
#  'selfcorrection': 4,
#  'standby mode': 6,
#  'swivel': 23,
#  'usb function': 3,
#  'viewing angles h  v typical': 15,
#  'wide gamut coverage typical': 5,
#  'a clear view to productivity': 4,
#  'stylish sturdy design': 4,
#  'monitor size': 3,
#  'virtual 4k': 10,
#  'input port': 3,
#  'dell warranty expiration date': 1,
#  'memory (ram)': 1,
#  'primary drive': 1,
#  'analog scanning frequency h  v': 11,
#  'auto ecoview  brightregulator': 12,
#  'digital scanning frequency h  v': 14,
#  'display size h x v': 14,
#  'panel size': 8,
#  'number of hdmi inputs': 6,
#  'hard drive interface': 4,
#  'ac power adapter': 3,
#  'stand/base': 3,
#  'additional information': 2,
#  'color depth number of colors': 5,
#  'color gamut cie1976': 3,
#  'contrast ratio typ': 3,
#  'ddcci': 5,
#  'dvid': 4,
#  'dynamic cr dcr': 3,
#  'epeat': 5,
#  'flicker safe': 3,
#  'hdcp': 6,
#  'intelligent auto auto resolution': 3,
#  'key lock': 3,
#  'original ratio': 3,
#  'picture mode': 3,
#  'reader mode': 3,
#  'super energy saving': 3,
#  'surface treatment': 5,
#  'contrast ratio dfc': 3,
#  'input': 12,
#  'viewing angle cr10': 5,
#  'interface output': 6,
#  'max vsync rate': 3,
#  'projector': 6,
#  'helping you go green': 3,
#  'sound system': 3,
#  'total hard drive capacity': 3,
#  'dimensions landscape w x h x d': 11,
#  'dimensions without stand w x h x d': 11,
#  'function': 11,
#  'net weight': 13,
#  'net weight without stand': 10,
#  'operating humidity rh non condensing': 11,
#  'others': 12,
#  'portsinterfaces': 4,
#  'supplied accessories': 12,
#  'sync formats': 8,
#  'ecoview sense': 5,
#  'output terminals': 7,
#  'sound adjustment': 7,
#  'active display size h v': 3,
#  'certifications and standards': 3,
#  'other settings': 4,
#  'tilt  swivel  pivot': 3,
#  'usb ports  standard': 4,
#  'viewing angles h v': 4,
#  'diagonal screen size': 14,
#  'image brightness': 14,
#  'inputs': 16,
#  'vesa compatible wall mount': 14,
#  'additional accesories': 11,
#  'battery plates': 11,
#  'connection cables': 11,
#  'depth mm': 11,
#  'height mm': 11,
#  'power adaptors': 11,
#  'product': 12,
#  'sunshade': 11,
#  'video outputs': 11,
#  'weight g': 11,
#  'width mm': 11,
#  'package type': 4,
#  '60 day nondoa warranty': 12,
#  'internet connection type': 1,
#  "what's included": 1,
#  'product depth with stand': 5,
#  'advanced features': 8,
#  'analog input': 5,
#  'colors supported': 8,
#  'epeat rated': 4,
#  'product depth without stand': 4,
#  'tm': 3,
#  'dot pitch': 5,
#  'input type': 5,
#  'number of ps2 ports': 3,
#  'number of usb ports': 5,
#  'dimensions whd': 3,
#  'viewing angle (horizontal/vertical)': 3,
#  'weight lbs': 3,
#  'part number': 1,
#  'builtin stereo speakers': 5,
#  'composite video': 6,
#  'kvm': 7,
#  'miscellaneous cdw': 3,
#  'output': 8,
#  'warranty - 3': 1,
#  'power savings mode': 3,
#  'color adjustment': 4,
#  'ecoview settings': 3,
#  'screen adjustment': 4,
#  'serial no.': 4,
#  'commercial display': 3,
#  'media player': 5,
#  'speaker system': 5,
#  'excellent visual performance': 4,
#  'stylish and userfriendly design for modern sophistication': 4,
#  'height rack units': 8,
#  '3d glasses': 5,
#  '3d requirements': 4,
#  'analogdigital': 4,
#  'basic': 4,
#  'eco mode': 6,
#  'light source': 5,
#  'osd': 5,
#  'choose your connection': 4,
#  'environmental footprint': 4,
#  'home is where the action is': 4,
#  'master performer': 4,
#  'slim and elegant design': 4,
#  'environmental design': 5,
#  'work smart not hard': 5,
#  'built in speakers': 3,
#  'general condition': 2,
#  'general description': 2,
#  'serial number': 5,
#  'quantity included': 4,
#  'reference': 4,
#  'sales includes': 4,
#  'colour': 5,
#  'colour support': 4,
#  'audio line in': 3,
#  'hard drive rpm': 3,
#  'number of usb 20 ports': 3,
#  'optical media supported': 3,
#  'power input': 3,
#  'no stand is included': 1,
#  '1000001 dynamic contrast ratio': 3,
#  'certified green': 3,
#  'size (gauge)': 2,
#  'process notes': 2,
#  'epeat qualified': 3,
#  'gaming series': 3,
#  'ips': 3,
#  'hp': 1,
#  'upc code': 3,
#  'analog': 4,
#  'integrated speakers': 5,
#  'power consumption max': 3,
#  'advanced technology for amazing visuals': 3,
#  'contemporary style unbeatable value': 3,
#  'hd cinematic widescreen': 3,
#  'model variations': 3,
#  'network  internet multimedia': 3,
#  'shipping width': 3,
#  'usb ports qty': 3,
#  'horizontal': 4,
#  'color temperature': 3,
#  'speaker': 3,
#  'description1': 1,
#  'approved agency': 5,
#  'peripherals': 5,
#  'power connection': 5,
#  'rs232': 5,
#  'dimensions w x d x h': 4,
#  'screen size (in.)': 1,
#  'compatible brand': 3,
#  'unit damage': 2,
#  'normal signs of use are present on these units': 4,
#  'usb ports': 4,
#  "what's in the box": 1,
#  '100 lakeview pkwy vernon hills il 60061': 3,
#  'brightness cdm2': 3,
#  'number of ps/2 ports': 2,
#  'signal input': 4,
#  'screen type': 1,
#  'screen format': 1,
#  'guides included': 1,
#  'original box': 1,
#  'manufacturer/supplier: dell, inc': 1,
#  'manufacture date': 1,
#  'item #': 1,
#  'functionality': 1,
#  'item appearance': 1,
#  'missing accessories': 1,
#  'compatiblity': 1,
#  'horizontal freq.': 1,
#  'vertical freq.': 1,
#  'adjustment': 1}

# %%
# remove attributes that appear less than 10% of the times in the products of a source
for source in sources2attributes:
    for attribute in list(sources2attributes.get(source).keys()):
        if sources2attributes.get(source).get(attribute) < 0.1 * len(sources2monitors.get(source)):
            sources2attributes.get(source).pop(attribute)

# %%
sources2attributes.get('www.ebay.com')
# Out:
# {'<page title>': 4281,
#  'brand': 2148,
#  'condition': 2405,
#  'display technology': 3247,
#  'screen size': 3495,
#  'aspect ratio': 2806,
#  'brightness': 2173,
#  'contrast ratio': 2733,
#  'max resolution': 1205,
#  'model': 3055,
#  'mpn': 2400,
#  'response time': 2715,
#  'video inputs': 1654,
#  'max. resolution': 1206,
#  'system': 1442,
#  'upc': 1762,
#  'features': 909,
#  'manufacturer': 580,
#  'maximum resolution': 508}

# %%
# create a dict source2dataframe where each dataframe contains the attributes of the products of a source
sources2dataframe = {}

for source in sources2attributes:
    attributes = list(sources2attributes.get(source).keys())
    df = pd.DataFrame(columns=attributes)
    for monitor in sources2monitors.get(source):
        row = []
        for attribute in attributes:
            if attribute in monitor:
                row.append(monitor.get(attribute))
            else:
                row.append(None)
        df.loc[len(df)] = row
    sources2dataframe[source] = df

# %%
sources2dataframe.get('www.ebay.com').head()
# Out:
#                                         <page title>    brand  \
# 0  CTL Black 17" LCD Monitor 171LX w Power and VG...      CTL
# 1  HP Compaq LE1711 17 inch LCD Monitor New Item ...       HP
# 2  Dell 24" Widescreen LED Backlight 1080p Full H...     None
# 3  New Samsung T27D390 Series 3 LED HDTV Monitor ...  Samsung
# 4                   Acer 17" Computer Monitor | eBay     Acer
#
#                                            condition display technology  \
# 0  Used: An item that has been used previously. T...                LCD
# 1                                               None                LCD
# 2  New: A brand-new, unused, unopened, undamaged ...            LED LCD
# 3  New: A brand-new, unused, unopened, undamaged ...            LED LCD
# 4  Used: An item that has been used previously. T...               None
#
#   screen size aspect ratio  brightness contrast ratio max resolution   model  \
# 0         17"         None        None           None           None    None
# 1         17"          5:4  250 cd/mÂ²           1000    1280 x 1024  LE1711
# 2         24"         16:9  250 cd/mÂ²           1000           None  E2414H
# 3         27"         16:9        None           None           None    None
# 4         17"         None        None           None           None    None
#
#                     mpn response time video inputs max. resolution   system  \
# 0                  None          None         None            None     None
# 1  EM886A8, EM886A8#ABA          5 ms    VGA D-Sub            None     None
# 2              320-9776          5 ms        DVI-D     1920 x 1080  Desktop
# 3                  None          None         None            None     None
# 4                  None          None         None            None  Desktop
#
#             upc features manufacturer maximum resolution
# 0          None     None         None               None
# 1          None     None         None               None
# 2  884116123446     None         None               None
# 3          None     None         None               None
# 4          None     None         None               None

# %%
# load the mediated schema from monitor_mediated_schema.txt
with open('dataset/monitor_mediated_schema.txt', 'r') as f:
    attributes = [line.strip() for line in f]
mediated_schema = pd.DataFrame(columns=attributes)

# load the ground truth from monitor_schema_matching_labelled_data.csv
ground_truth = pd.read_csv('dataset/monitor_schema_matching_labelled_data.csv')
ground_truth.head(2)
# Out:
#                                  source_attribute_id   target_attribute_name
# 0  www.planet-computer.it//dimensione visibile or...  screen_size_horizontal
# 1                    www.pc-canada.com//product name    screen_size_diagonal

# %%
# create a dict source2ground_truth using a list of pairs (source_attribute_id, target_attribute_name)
sources2ground_truth = {}

for source, target in ground_truth.values:
    # split the string to get the source and the attribute
    source_attribute = source.split('//')
    if source_attribute[0] in sources2ground_truth:
        sources2ground_truth.get(source_attribute[0]).append((source_attribute[1], target))
    else:
        sources2ground_truth[source_attribute[0]] = [(source_attribute[1], target)]

# %%
sources2ground_truth.get('www.ebay.com')
# Out:
# [('display format', 'supported_resolution'),
#  ('scan format', 'supported_resolution'),
#  ('display response time', 'response_time'),
#  ('image aspect ratio', 'supported_aspect_ratio'),
#  ('dvid', 'dvid_port_quantity'),
#  ('dvid', 'has_dvid_port'),
#  ('vga input', 'has_vga_port'),
#  ('microphone', 'has_microphone'),
#  ('support details full contract period', 'warranty_duration'),
#  ('number of dvi', 'dvi_port_quantity'),
#  ('bluetooth', 'bluetooth'),
#  ('screen refresh rate', 'vertical_refresh_rate_max'),
#  ('screen refresh rate', 'vertical_refresh_rate_range')]

# %%
# Instantiate matcher and run
# Coma requires java to be installed on your machine
matcher = Coma(max_n=10, strategy="COMA_OPT_INST")

output = pd.DataFrame(columns=['source_attribute_id', 'target_attribute_name'])
i = 1

for source in sources2dataframe:
    print(i,"/",len(sources2dataframe), "source:", source)
    df = sources2dataframe.get(source)
    matches = valentine_match(df, mediated_schema, matcher)
    for (_,a1), (_,a2) in matches:
        output.loc[len(output)] = [source+'//'+a1, a2]
    i += 1
        
pd.DataFrame.to_csv(output, 'coma_output_predictions.csv', index=False)
# Out:
# 1 / 26 source: ca.pcpartpicker.com
# 2 / 26 source: catalog.com
# 3 / 26 source: ce.yikus.com
# 4 / 26 source: www.best-deal-items.com
# 5 / 26 source: www.cleverboxes.com
# 6 / 26 source: www.ebay.com
# 7 / 26 source: www.getprice.com.au
# 8 / 26 source: www.hardware-planet.it
# 9 / 26 source: www.imldirect.it
# 10 / 26 source: www.itenergy.co.uk
# 11 / 26 source: www.jrlinton.co.uk
# 12 / 26 source: www.kingsfieldcomputers.co.uk
# 13 / 26 source: www.makingbuyingeasy.co.uk
# 14 / 26 source: www.mediashopuk.com
# 15 / 26 source: www.mrhightech.com
# 16 / 26 source: www.nexus-t.co.uk
# 17 / 26 source: www.odsi.co.uk
# 18 / 26 source: www.officedepot.com
# 19 / 26 source: www.ohc24.ch
# 20 / 26 source: www.pc-canada.com
# 21 / 26 source: www.pcconnection.com
# 22 / 26 source: www.planet-computer.it
# 23 / 26 source: www.shopmania.com
# 24 / 26 source: www.softwarecity.ca
# 25 / 26 source: www.vology.com
# 26 / 26 source: www.xpcpro.com

# %%
# Instantiate matcher and run
matcher = Cupid(w_struct=0.4, leaf_w_struct=0.4, th_accept=0.9, parallelism=16)

output = pd.DataFrame(columns=['source_attribute_id', 'target_attribute_name'])
i = 1

for source in sources2dataframe:
    print(i,"/",len(sources2dataframe), " source:", source)
    df = sources2dataframe.get(source)
    matches = valentine_match(df, mediated_schema, matcher)
    for (_,a1), (_,a2) in matches:
        output.loc[len(output)] = [source+'//'+a1, a2]
    i += 1
    
    pd.DataFrame.to_csv(output, 'cupid_output_predictions.csv', index=False)
# Out:
# 1 / 26  source: ca.pcpartpicker.com
# 2 / 26  source: catalog.com
# 3 / 26  source: ce.yikus.com
# 4 / 26  source: www.best-deal-items.com
# 5 / 26  source: www.cleverboxes.com
# 6 / 26  source: www.ebay.com
# 7 / 26  source: www.getprice.com.au
# 8 / 26  source: www.hardware-planet.it
# 9 / 26  source: www.imldirect.it
# 10 / 26  source: www.itenergy.co.uk
# 11 / 26  source: www.jrlinton.co.uk
# 12 / 26  source: www.kingsfieldcomputers.co.uk
# 13 / 26  source: www.makingbuyingeasy.co.uk
# 14 / 26  source: www.mediashopuk.com
